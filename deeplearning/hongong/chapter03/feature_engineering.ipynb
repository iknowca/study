# %%
import pandas as pd

df = pd.read_csv('https://bit.ly/perch_csv_data')
perch_full = df.to_numpy()
print(perch_full)
# Out:
# [[ 8.4   2.11  1.41]
#  [13.7   3.53  2.  ]
#  [15.    3.82  2.43]
#  [16.2   4.59  2.63]
#  [17.4   4.59  2.94]
#  [18.    5.22  3.32]
#  [18.7   5.2   3.12]
#  [19.    5.64  3.05]
#  [19.6   5.14  3.04]
#  [20.    5.08  2.77]
#  [21.    5.69  3.56]
#  [21.    5.92  3.31]
#  [21.    5.69  3.67]
#  [21.3   6.38  3.53]
#  [22.    6.11  3.41]
#  [22.    5.64  3.52]
#  [22.    6.11  3.52]
#  [22.    5.88  3.52]
#  [22.    5.52  4.  ]
#  [22.5   5.86  3.62]
#  [22.5   6.79  3.62]
#  [22.7   5.95  3.63]
#  [23.    5.22  3.63]
#  [23.5   6.28  3.72]
#  [24.    7.29  3.72]
#  [24.    6.38  3.82]
#  [24.6   6.73  4.17]
#  [25.    6.44  3.68]
#  [25.6   6.56  4.24]
#  [26.5   7.17  4.14]
#  [27.3   8.32  5.14]
#  [27.5   7.17  4.34]
#  [27.5   7.05  4.34]
#  [27.5   7.28  4.57]
#  [28.    7.82  4.2 ]
#  [28.7   7.59  4.64]
#  [30.    7.62  4.77]
#  [32.8  10.03  6.02]
#  [34.5  10.26  6.39]
#  [35.   11.49  7.8 ]
#  [36.5  10.88  6.86]
#  [36.   10.61  6.74]
#  [37.   10.84  6.26]
# ...

# %%
import numpy as np

perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight, random_state=42)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(include_bias=False)
poly.fit(train_input)
train_poly = poly.transform(train_input)
print(train_poly.shape)
# Out:
# (42, 9)

# %%
poly.get_feature_names_out()
# Out:
# array(['x0', 'x1', 'x2', 'x0^2', 'x0 x1', 'x0 x2', 'x1^2', 'x1 x2',
#        'x2^2'], dtype=object)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))
# Out:
# 0.9903183436982125

# %%
test_poly = poly.transform(test_input)
print(lr.score(test_poly, test_target))
# Out:
# 0.9714559911594167

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_poly)
train_scaled = ss.transform(train_poly)
test_scaled = ss.transform(test_poly)

# %%
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(train_scaled, train_target)
print(ridge.score(train_scaled, train_target))
# Out:
# 0.9857915060511934

# %%
print(ridge.score(test_scaled, test_target))
# Out:
# 0.9835057194929057

# %%
train_score = []
test_score = []

alpha_list = np.linspace(-3, 2, 100)
for alpha in alpha_list:
    ridge = Ridge(alpha=10**alpha)
    ridge.fit(train_scaled, train_target)
    train_score.append(ridge.score(train_scaled, train_target))
    test_score.append(ridge.score(test_scaled, test_target))

# %%
import matplotlib.pyplot as plt
plt.plot(alpha_list, train_score, label='train')
plt.plot(alpha_list, test_score, label='test')
plt.xlabel("alpha")
plt.ylabel(r"$R^2$")
plt.legend()
plt.title("find alpha - Ridge")
# Out:
# Text(0.5, 1.0, 'find alpha - Ridge')

# %%
max_alpha = alpha_list[np.argmax(test_score)]
print("alpha: ", 10**max_alpha)

ridge = Ridge(alpha=10**max_alpha)
ridge.fit(train_scaled, train_target)
print("train score: ", ridge.score(train_scaled, train_target))
print("test score: ", ridge.score(test_scaled, test_target))
# Out:
# alpha:  0.3351602650938841
# train score:  0.9881596171330602
# test score:  0.9869400695977246

# %%
from sklearn.linear_model import Lasso

lasso = Lasso()
lasso.fit(train_scaled, train_target)
print(ridge.score(train_scaled, train_target))
# Out:
# 0.9881596171330602

# %%
train_score = []
test_score = []

alpha_list = np.linspace(-3, 2, 1000)
for alpha in alpha_list:
    lasso = Lasso(alpha=10**alpha)
    lasso.fit(train_scaled, train_target)
    train_score.append(lasso.score(train_scaled, train_target))
    test_score.append(lasso.score(test_scaled, test_target))
# Out:
# /Users/iknow/Desktop/study/deeplearning/hongong/.venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.903e+04, tolerance: 5.183e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/iknow/Desktop/study/deeplearning/hongong/.venv/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.903e+04, tolerance: 5.183e+02
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(alpha_list, train_score, label='train')
plt.plot(alpha_list, test_score, label='test')
plt.xlabel("alpha")
plt.ylabel(r"$R^2$")
plt.legend()
plt.title("find alpha - Lasso")
# Out:
# Text(0.5, 1.0, 'find alpha - Lasso')

# %%
max_alpha = alpha_list[np.argmax(test_score)]
print("alpha: ", 10**max_alpha)

ridge = Ridge(alpha=10**max_alpha)
ridge.fit(train_scaled, train_target)
print("train score: ", ridge.score(train_scaled, train_target))
print("test score: ", ridge.score(test_scaled, test_target))
# Out:
# alpha:  0.5342293299538352
# train score:  0.9874160088627314
# test score:  0.9863791738888561

# %%
# Out:
# array([29.44662056, 29.7803342 , 28.9298673 , 31.31962257, 31.6217746 ,
#        31.17516088, 31.64574449, 31.19347173, 30.44125738])
